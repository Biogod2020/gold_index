# %%
import seaborn as sns

# %%
import pandas as pd

# %%
df = pd.read_csv('./inn_moranI.csv')

# %%
df
# Out:
#            fine  Moran's I        P-value  num_cell   sample region_abb  \
# 0      InN-Sncg   0.007849   0.000000e+00      1175  HZ12M01         BF
# 1     InN-Calb2   0.005691   0.000000e+00      2563  HZ12M01         BF
# 2     InN-Erbb4   0.003275  5.915726e-220      1097  HZ12M01         BF
# 3     InN-Pvalb   0.000368   2.710213e-14       243  HZ12M01         BF
# 4       InN-Sst  -0.000557   4.418474e-08       301  HZ12M01         BF
# ...         ...        ...            ...       ...      ...        ...
# 1266  InN-Calb2   0.003120   2.468387e-59       566   HZ8M06         TH
# 1267  InN-Pvalb   0.002404   2.780207e-07       217   HZ8M06         TH
# 1268    InN-Vip   0.000063   1.179925e-03        47   HZ8M06         TH
# 1269    InN-Sst  -0.004588   4.278761e-02       138   HZ8M06         TH
# 1270  InN-Lamp5  -0.059421   2.171429e-01        15   HZ8M06         TH
#
#                   fullid
# 0     HZ12M01_coorect_BF
# 1     HZ12M01_coorect_BF
# ...

# %%
# cellbin_moran/pl/palettes.py

cell_type_colors = {
    'Astro-1': '#FF8C00',
    'Astro-2': '#FFC30A',
    'Astro-3': '#F17F32',
    'Astro-4': '#FFB77F',
    'Astro-5': '#F39942',
    'Astro-6': '#E9D134',
    'Endo': '#996B2D',
    'ExN-CA1': '#AA0DFD',
    'ExN-CA2': '#F18266',
    'ExN-CA3': '#F9A206',
    'ExN-DEGLU-1': '#6B5CA4',
    'ExN-DEGLU-2': '#444A9B',
    'ExN-DG': '#584925',
    'ExN-L2/3-IT': '#F90086',
    'ExN-L4/5-IT': '#60E1A3',
    'ExN-L5-ET': '#1B4331',
    'ExN-L5-IT': '#D00000',
    'ExN-L5/6-NP': '#CCFF33',
    'ExN-L6-CT': '#F853ED',
    'ExN-L6-IT': '#EF9FFF',
    'ExN-L6b': '#6FDF00',
    'ExN-Olf': '#FF6600',
    'InN-Calb2': '#3183FD',
    'InN-Erbb4': '#0095C6',
    'InN-Lamp5': '#03045E',
    'InN-Olf': '#9D0207',
    'InN-Pvalb': '#15F1F1',
    'InN-Sncg': '#076275',
    'InN-Sst': '#CAE1FF',
    'InN-Vip': '#90DFEE',
    'Micro-1': '#B099FF',
    'Micro-2': '#450099',
    'Micro-3': '#8481BA',
    'Micro-4': '#B395BD',
    'MSN': '#0D46A0',
    'Olig-1': '#007100',
    'Olig-2': '#9EEF1A',
    'Olig-3': '#38AF00',
    'Olig-4': '#34923C',
    'Olig-5': '#13756D',
    'Olig-6': '#48C0AA',
    'OPC-1': '#01D569',
    'OPC-2': '#6E9B58',
    'Peri': '#858781',
    'SMC': '#825F45',
    'ChN': '#B06C6A',
    
}

general_type_colors = {
    'ExN': '#FF3357',
    'InN': '#2B92DF',
    'Astro': '#FF7620',
    'Micro': '#820E56',
    'Olig': '#099963',
    'OPC': '#73E785',
    'Vas': '#523691',
    'Endo': '#996B2D',
    'MSN': '#0D46A0',
    'Peri': '#858781',
    'SMC': '#825F45'
}

brain_region_colors = {
    'BF': '#341FCC',
    'ENT': '#992D6A',
    'ECT': '#992D6A',
    'HPF': '#D974E8',
    'PFC': '#CC0025',
    'RS': '#FF6F80',
    'STR': '#009909',
    'TH': '#25ADFF',
    "Basal forebrain": "#341FCC",
    "Entorhinal area": "#992D6A",
    "Ectorhinal area": "#992D6A",
    "Hippocampal formation": "#D974E8",
    "Prefrontal cortex": "#CC0025",
    "Retrosplenial area": "#FF6F80",
    "Striatum": "#009909",
    "Thalamus": "#25ADFF"
}

age_group_colors = {
    '2M': '#e64b35',
    '3M': '#4dbbd5',
    '4M': '#00a087',
    '5M': '#f39b7f',
    '6M': '#3c5488',
    '8M': '#8491b4',
    '12M': '#91d1c2'
}

# %%
real_celldict = {'PFC': ['ExN-L5-ET',
  'ExN-L6-CT',
  'ExN-L2/3-IT',
  'ExN-L6-IT',
  'ExN-L4/5-IT',
  'InN-Pvalb',
  'InN-Vip',
  'ExN-L5-IT',
  'Micro-2',
  'ExN-L5/6-NP',
  'InN-Lamp5',
  'InN-Sst',
  'SMC',
  'Peri',
  'Astro-1',
  'OPC-1',
  'Olig-1',
  'Endo',
  'Olig-6',
  'Olig-2',
  'Micro-1',
  'Olig-5',
  'Olig-3',
  'Astro-4',
  'Astro-2',
  'Micro-4',
  'Astro-5',
  'Micro-3',
  'Astro-3',
  'Astro-6',
  'Olig-4',
  'OPC-2'],
 'BF': ['InN-Calb2',
  'InN-Sst',
  'InN-Lamp5',
  'MSN',
  'Olig-2',
  'InN-Pvalb',
  'Olig-1',
  'Astro-2',
  'ExN-L6-IT',
  'ExN-L5-ET',
  'InN-Olf',
  'Olig-5',
  'Olig-3',
  'OPC-2',
  'Olig-4',
  'ExN-Olf',
  'Olig-6',
  'ExN-L6-CT',
  'Peri',
  'Astro-1',
  'OPC-1',
  'Endo',
  'SMC',
  'ExN-L5-IT',
  'Astro-6',
  'Astro-4',
  'Micro-3',
  'Micro-2',
  'Micro-1',
  'Astro-3',
  'Astro-5',
  'Micro-4'],
 'STR': ['MSN',
  'ExN-L6-IT',
  'Endo',
  'InN-Sst',
  'InN-Pvalb',
  'ExN-L6-CT',
  'ExN-L5-IT',
  'InN-Olf',
  'ExN-L4/5-IT',
  'Olig-2',
  'Olig-4',
  'Olig-6',
  'Micro-2',
  'ExN-L6b',
  'ExN-L5/6-NP',
  'ExN-L5-ET',
  'Peri',
  'Olig-3',
  'Olig-1',
  'Olig-5',
  'OPC-2',
  'Astro-6',
  'Micro-3',
  'SMC',
  'Astro-1',
  'Astro-5',
  'Micro-1',
  'OPC-1',
  'Astro-4',
  'Astro-2',
  'Micro-4',
  'Astro-3'],
 'TH': ['ExN-DEGLU-2',
  'Olig-2',
  'ExN-DEGLU-1',
  'InN-Pvalb',
  'InN-Lamp5',
  'MSN',
  'InN-Calb2',
  'InN-Sst',
  'Olig-3',
  'Olig-1',
  'ExN-L6-CT',
  'Endo',
  'ExN-Olf',
  'Peri',
  'Olig-5',
  'Astro-4',
  'SMC',
  'Astro-1',
  'Micro-2',
  'OPC-2',
  'Micro-3',
  'Micro-4',
  'Micro-1',
  'Astro-6',
  'Olig-6',
  'ExN-L5-IT',
  'Astro-5',
  'Astro-3',
  'OPC-1',
  'Astro-2',
  'Olig-4'],
 'HPF': ['InN-Erbb4',
  'ExN-CA1',
  'ExN-DG',
  'InN-Pvalb',
  'ExN-CA3',
  'Olig-1',
  'InN-Vip',
  'OPC-1',
  'Olig-2',
  'Astro-1',
  'SMC',
  'InN-Sncg',
  'Olig-5',
  'InN-Lamp5',
  'Peri',
  'Astro-4',
  'Olig-6',
  'InN-Sst',
  'Olig-3',
  'Astro-6',
  'ExN-CA2',
  'Astro-2',
  'Endo',
  'Micro-4',
  'Astro-3',
  'Astro-5',
  'Micro-2',
  'Micro-1',
  'OPC-2',
  'Micro-3',
  'Olig-4'],
 'ECT': ['InN-Sst',
  'InN-Erbb4',
  'ExN-L2/3-IT',
  'ExN-Olf',
  'InN-Lamp5',
  'ExN-L4/5-IT',
  'ExN-L6-CT',
  'OPC-1',
  'ExN-L6-IT',
  'InN-Vip',
  'Astro-2',
  'Astro-5',
  'Astro-1',
  'Peri',
  'Micro-1',
  'ExN-L5-ET',
  'Olig-6',
  'Endo',
  'Astro-3',
  'Astro-4',
  'SMC',
  'Micro-2',
  'Olig-3',
  'OPC-2',
  'MSN',
  'Astro-6',
  'Olig-1',
  'Olig-5',
  'Olig-2',
  'Micro-3',
  'Micro-4',
  'Olig-4'],
 'RS': ['ExN-L5-ET',
  'ExN-L6-IT',
  'InN-Vip',
  'ExN-L5-IT',
  'InN-Sst',
  'InN-Pvalb',
  'ExN-L6-CT',
  'ExN-L5/6-NP',
  'ExN-L2/3-IT',
  'ExN-L4/5-IT',
  'InN-Lamp5',
  'Olig-6',
  'Peri',
  'Astro-1',
  'Olig-3',
  'InN-Sncg',
  'SMC',
  'Olig-2',
  'Olig-1',
  'Micro-2',
  'Micro-1',
  'OPC-1',
  'Endo',
  'Astro-5',
  'Olig-5',
  'Astro-4',
  'Astro-2',
  'Astro-3',
  'Micro-4',
  'Olig-4',
  'Astro-6',
  'Micro-3',
  'OPC-2']}

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats

# Define the significance threshold for the t-test
significance_level = 0.05

# Get unique regions
regions = df['region_abb'].unique()

# Set up the figure with subplots (1 row, number of unique regions)
fig, axes = plt.subplots(1, len(regions), figsize=(20, 10), sharey=True)

# Loop through each region and plot
for i, region in enumerate(regions):
    # Filter data for each region
    data = df[df['region_abb'] == region]
    
    # Filter data to include only the 'fine' values in real_celldict for the current region
    data = data[data['fine'].isin(real_celldict[region])]
    
    # Create a boxplot for each subplot with alpha set to 0.7
    sns.boxplot(x="Moran's I", y='fine', data=data, ax=axes[i], palette=cell_type_colors, boxprops=dict(alpha=0.7))
    
    # Set the title for each subplot
    axes[i].set_title(region)
    
    # Set x-axis limits
    axes[i].set_xlim(-0.005, 0.025)
    
    # # Loop through each 'fine' category to perform the one-tailed t-test
    # for j, fine_type in enumerate(data['fine'].unique()):
    #     fine_data = data[data['fine'] == fine_type]["Moran's I"]
        
    #     # Perform a one-tailed t-test (greater than 0)
    #     t_stat, p_value_two_tailed = stats.ttest_1samp(fine_data, 0)
        
    #     # Convert the two-tailed p-value to a one-tailed p-value
    #     p_value_one_tailed = p_value_two_tailed / 2 if t_stat > 0 else 1.0
        
    #     # Check if the one-tailed p-value is significant
    #     if p_value_one_tailed < significance_level:
    #         # Add a single asterisk at the x = 0.015 position
    #         axes[i].text(0.015, j, '*', ha='center', va='center', color='red', fontsize=12)

# Adjust layout to avoid overlap
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# /var/folders/f_/dlk4nftn5s3bpdrpz9trm07m0000gn/T/ipykernel_7777/2181957387.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Moran's I", y='fine', data=data, ax=axes[i], palette=cell_type_colors, boxprops=dict(alpha=0.7))
# /Users/jay/micromamba/envs/stalign/lib/python3.11/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/jay/micromamba/envs/stalign/lib/python3.11/site-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from scipy import stats
from scipy.stats import wilcoxon

# Load the data
df = pd.read_csv('./inn_moranI.csv')

# Define the significance threshold for the Wilcoxon test
significance_level = 0.05

# Get unique regions
regions = df['region_abb'].unique()

# Set up the figure with subplots (1 row, number of unique regions)
fig, axes = plt.subplots(1, len(regions), figsize=(20, 6), sharey=True)

# Loop through each region and plot
for i, region in enumerate(regions):
    # Filter data for each region
    data = df[df['region_abb'] == region]
    
    # Filter data to include only the 'fine' values in real_celldict for the current region
    data = data[data['fine'].isin(real_celldict[region])]
    
    # Set x-axis limits
    x_min, x_max = -0.005, 0.025
    
    # Filter data to include only points within the x-axis limits
    data_filtered = data[(data["Moran's I"] >= x_min) & (data["Moran's I"] <= x_max)]
    
    # Create a boxplot for each subplot with alpha set to 0.7
    sns.boxplot(x="Moran's I", y='fine', data=data, ax=axes[i], palette=cell_type_colors, boxprops=dict(alpha=0.7), fliersize=0,
                linewidth=0.5)
    
    # Add a strip plot for each box plot, using the filtered data
    sns.stripplot(x="Moran's I", y='fine', data=data_filtered, ax=axes[i], palette=cell_type_colors, alpha=0.5, jitter=True, 
                  edgecolor='grey', linewidth=0.2)
    
    # Add a red vertical dashed line at x=0
    axes[i].axvline(x=0, color='red', linestyle='--')
    
    # Set the title for each subplot
    axes[i].set_title(region)
    
    # Set x-axis limits
    axes[i].set_xlim(x_min, x_max)
    
    # Loop through each category ('fine') in the region
    for j, fine_category in enumerate(data['fine'].unique()):
        # Extract Moran's I values for this fine category
        morans_i_values = data[data['fine'] == fine_category]["Moran's I"]
        
        # Check if there are enough values to perform the test (Wilcoxon requires at least 2)
        if len(morans_i_values) > 1:
            # Perform a one-sample Wilcoxon signed-rank test against 0
            stat, p_value = wilcoxon(morans_i_values - 0, alternative='greater')
            
            # Check if the p-value is less than the significance level
            if p_value < significance_level:
                # Add an asterisk to the right tick of the box corresponding to this fine category
                axes[i].text(0.02, j, '*', color='red', fontsize=20, va='center')

# Adjust layout to prevent overlap
plt.tight_layout()
plt.savefig('/Users/jay/LocalProjects/cellbin_moranI/sup_fig_nb/boxplot_moranI_inn.pdf', dpi=300)
plt.show()
# Out:
# /var/folders/f_/dlk4nftn5s3bpdrpz9trm07m0000gn/T/ipykernel_23632/3049337172.py:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Moran's I", y='fine', data=data, ax=axes[i], palette=cell_type_colors, boxprops=dict(alpha=0.7), fliersize=0,
# /Users/jay/micromamba/envs/stalign/lib/python3.11/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/jay/micromamba/envs/stalign/lib/python3.11/site-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
from scipy.stats import wilcoxon

df = pd.read_csv('./inn_moranI.csv')

# Define the significance threshold for the Wilcoxon test
significance_level = 0.05

# Get unique regions
regions = df['region_abb'].unique()

# Set up the figure with subplots (1 row, number of unique regions)
fig, axes = plt.subplots(1, len(regions), figsize=(20, 6), sharey=True)

# Loop through each region and plot
for i, region in enumerate(regions):
    # Filter data for each region
    data = df[df['region_abb'] == region]
    
    # Filter data to include only the 'fine' values in real_celldict for the current region
    data = data[data['fine'].isin(real_celldict[region])]
    
    # Create a boxplot for each subplot with alpha set to 0.7
    sns.boxplot(x="Moran's I", y='fine', data=data, ax=axes[i], palette=cell_type_colors, boxprops=dict(alpha=0.7), fliersize=0,
                linewidth=0.5)
    
    # Add a strip plot for each box plot
    sns.stripplot(x="Moran's I", y='fine', data=data, ax=axes[i], palette=cell_type_colors, alpha=0.5, jitter=True, 
                  edgecolor='grey', linewidth=0.2)
    
    # Add a red vertical dashed line at x=0
    axes[i].axvline(x=0, color='red', linestyle='--')
    
    # Set the title for each subplot
    axes[i].set_title(region)
    
    # Set x-axis limits
    axes[i].set_xlim(-0.005, 0.025)
    
    # Loop through each category ('fine') in the region
    for j, fine_category in enumerate(data['fine'].unique()):
        # Extract Moran's I values for this fine category
        morans_i_values = data[data['fine'] == fine_category]["Moran's I"]
        
        # Check if there are enough values to perform the test (Wilcoxon requires at least 2)
        if len(morans_i_values) > 1:
            # Perform a one-sample Wilcoxon signed-rank test against 0
            stat, p_value = wilcoxon(morans_i_values - 0, alternative='greater')
            
            # Check if the p-value is less than the significance level
            if p_value < significance_level:
                # Add an asterisk to the right tick of the box corresponding to this fine category
                axes[i].text(0.02, j, '*', color='red', fontsize=20, va='center')

# Adjust layout to prevent overlap
plt.tight_layout()
plt.savefig('/Users/jay/LocalProjects/cellbin_moranI/sup_fig_nb/boxplot_moranI_inn.pdf', dpi=300)
plt.show()
# Out:
# /var/folders/f_/dlk4nftn5s3bpdrpz9trm07m0000gn/T/ipykernel_23632/2013010441.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Moran's I", y='fine', data=data, ax=axes[i], palette=cell_type_colors, boxprops=dict(alpha=0.7), fliersize=0,
# /Users/jay/micromamba/envs/stalign/lib/python3.11/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/jay/micromamba/envs/stalign/lib/python3.11/site-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# ...

# %%
import os

# %%
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 os.getcwd()
#
# FileNotFoundError: [Errno 2] No such file or directory

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
from scipy import stats
from scipy.stats import wilcoxon

exn_df = pd.read_csv('ExN_dist_moranI.csv')

# Define the significance threshold for the Wilcoxon test
significance_level = 0.05

# Get unique regions
regions = exn_df['region_abb'].unique()

# Set up the figure with subplots (1 row, number of unique regions)
fig, axes = plt.subplots(1, len(regions), figsize=(20, 6), sharey=True)

# Loop through each region and plot
for i, region in enumerate(regions):
    # Filter data for each region
    data = exn_df[exn_df['region_abb'] == region]
    
    # Filter data to include only the 'fine' values in real_celldict for the current region
    data = data[data['fine'].isin(real_celldict[region])]
    
    # Create a boxplot for each subplot with alpha set to 0.7
    sns.boxplot(x="Moran's I", y='fine', data=data, ax=axes[i], palette=cell_type_colors, boxprops=dict(alpha=0.7), fliersize=0,
                linewidth=0.5)
    
    # Add a strip plot for each box plot
    sns.stripplot(x="Moran's I", y='fine', data=data, ax=axes[i], palette=cell_type_colors, alpha=0.5, jitter=True, 
                  edgecolor='grey', linewidth=0.2)
    
    # Set the title for each subplot
    axes[i].set_title(region)
    
    # Set x-axis limits
    axes[i].set_xlim(-0.01, 0.03) # y:x=580
    # axes[i].set_aspect(1/580)

    # Add a red vertical dashed line at x=0
    axes[i].axvline(x=0, color='red', linestyle='--')
    
    # Loop through each category ('fine') in the region
    for j, fine_category in enumerate(data['fine'].unique()):
        # Extract Moran's I values for this fine category
        morans_i_values = data[data['fine'] == fine_category]["Moran's I"]
        
        # Check if there are enough values to perform the test (Wilcoxon requires at least 2)
        if len(morans_i_values) > 1:
            # Perform a one-sample Wilcoxon signed-rank test against 0
            stat, p_value = wilcoxon(morans_i_values - 0, alternative='greater')
            
            # Check if the p-value is less than the significance level
            if p_value < significance_level:
                # Add an asterisk to the right tick of the box corresponding to this fine category
                axes[i].text(0.017, j, '*', color='red', fontsize=20, va='center')

    # After plotting, get and print the y:x scale (limits)
    x_lim = axes[i].get_xlim()
    y_lim = axes[i].get_ylim()
    print(f'Subplot {i+1} ({region}): x-lim = {x_lim}, y-lim = {y_lim}')
    

# Adjust layout to prevent overlap
plt.tight_layout()
plt.savefig('/Users/jay/LocalProjects/cellbin_moranI/sup_fig_nb/exn_boxplot_moranI.pdf', dpi=300)
plt.show()
# Out:
# /var/folders/f_/dlk4nftn5s3bpdrpz9trm07m0000gn/T/ipykernel_23632/23884549.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Moran's I", y='fine', data=data, ax=axes[i], palette=cell_type_colors, boxprops=dict(alpha=0.7), fliersize=0,
# /Users/jay/micromamba/envs/stalign/lib/python3.11/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/jay/micromamba/envs/stalign/lib/python3.11/site-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# ...

# %%
mask = exn_df['region_abb'] == 'HPF'
exn_df[mask]

sns.boxplot(x="Moran's I", y='fine', data=exn_df[mask], palette=cell_type_colors, fliersize=0)
# Calculate the significance level for the HPF region
for fine_category in exn_df[mask]['fine'].unique():
    morans_i_values = exn_df[mask & (exn_df['fine'] == fine_category)]["Moran's I"]
    
    if len(morans_i_values) > 1:
        stat, p_value = wilcoxon(morans_i_values - 0, alternative='greater')
        
        if p_value < significance_level:
            plt.text(0.02, list(exn_df[mask]['fine'].unique()).index(fine_category), '*', color='red', fontsize=20, va='center')
# Out:
# /var/folders/f_/dlk4nftn5s3bpdrpz9trm07m0000gn/T/ipykernel_23632/1489561701.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Moran's I", y='fine', data=exn_df[mask], palette=cell_type_colors, fliersize=0)
# /Users/jay/micromamba/envs/stalign/lib/python3.11/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/jay/micromamba/envs/stalign/lib/python3.11/site-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
from scipy import stats
from scipy.stats import wilcoxon

exn_df = pd.read_csv('ExN_dist_moranI.csv')

# Define the significance threshold for the Wilcoxon test
significance_level = 0.05

# Get unique regions
regions = exn_df['region_abb'].unique()

# Set up the figure with subplots (1 row, number of unique regions), sharey=True to share y-axis
fig, axes = plt.subplots(1, len(regions), figsize=(20, 6), sharey=True)

# Define the fixed y-limits and x-limits ratio
fixed_y_lim = (14.5, -0.5)
fixed_y_range = fixed_y_lim[0] - fixed_y_lim[1]  # y-range = 15.0
fixed_x_lim = (-0.005, 0.02)
fixed_x_range = fixed_x_lim[1] - fixed_x_lim[0]  # x-range = 0.025

# Loop through each region and plot
for i, region in enumerate(regions):
    # Filter data for each region
    data = exn_df[exn_df['region_abb'] == region]
    
    # Filter data to include only the 'fine' values in real_celldict for the current region
    data = data[data['fine'].isin(real_celldict[region])]
    
    # Create a boxplot for each subplot with alpha set to 0.7
    sns.boxplot(x="Moran's I", y='fine', data=data, ax=axes[i], palette=cell_type_colors, boxprops=dict(alpha=0.7), fliersize=0)
    
    # Add a strip plot for each box plot
    sns.stripplot(x="Moran's I", y='fine', data=data, ax=axes[i], palette=cell_type_colors, alpha=0.5, jitter=True, 
                  edgecolor='grey', linewidth=1)
    
    # Set the title for each subplot
    axes[i].set_title(region)
    
    # Calculate the dynamic x-limits based on the data
    current_x_lim = axes[i].get_xlim()
    current_x_range = current_x_lim[1] - current_x_lim[0]  # Get the current x-range
    
    # Calculate scaling factor based on the fixed y:x ratio
    scale_factor = current_x_range / fixed_x_range
    
    # Adjust the x-limits to maintain the same y:x ratio
    new_x_lim = (current_x_lim[0], current_x_lim[0] + scale_factor * fixed_x_range)
    axes[i].set_xlim(new_x_lim)

    # Set the fixed y-limits for all subplots (because sharey=True, this is applied to all)
    axes[i].set_ylim(fixed_y_lim)

    # Add a red vertical dashed line at x=0
    axes[i].axvline(x=0, color='red', linestyle='--')
    
    # Loop through each category ('fine') in the region
    for j, fine_category in enumerate(data['fine'].unique()):
        # Extract Moran's I values for this fine category
        morans_i_values = data[data['fine'] == fine_category]["Moran's I"]
        
        # Check if there are enough values to perform the test (Wilcoxon requires at least 2)
        if len(morans_i_values) > 1:
            # Perform a one-sample Wilcoxon signed-rank test against 0
            stat, p_value = wilcoxon(morans_i_values - 0, alternative='greater')
            
            # Check if the p-value is less than the significance level
            if p_value < significance_level:
                # Add an asterisk to the right tick of the box corresponding to this fine category
                axes[i].text(0.017, j, '*', color='red', fontsize=20, va='center')

# Adjust layout to prevent overlap
plt.tight_layout()
plt.savefig('/Users/jay/LocalProjects/cellbin_moranI/sup_fig_nb/exn_boxplot_moranI_freex.pdf', dpi=300)
plt.show()
# Out:
# /var/folders/f_/dlk4nftn5s3bpdrpz9trm07m0000gn/T/ipykernel_23632/2133566152.py:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Moran's I", y='fine', data=data, ax=axes[i], palette=cell_type_colors, boxprops=dict(alpha=0.7), fliersize=0)
# /Users/jay/micromamba/envs/stalign/lib/python3.11/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/jay/micromamba/envs/stalign/lib/python3.11/site-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# ...
