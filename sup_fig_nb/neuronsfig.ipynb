# %%
import seaborn as sns

# %%
import pandas as pd

# %%
df = pd.read_csv('./inn_moranI.csv')

# %%
df
# Out:
#            fine  Moran's I        P-value  num_cell   sample region_abb  \
# 0      InN-Sncg   0.007849   0.000000e+00      1175  HZ12M01         BF
# 1     InN-Calb2   0.005691   0.000000e+00      2563  HZ12M01         BF
# 2     InN-Erbb4   0.003275  5.915726e-220      1097  HZ12M01         BF
# 3     InN-Pvalb   0.000368   2.710213e-14       243  HZ12M01         BF
# 4       InN-Sst  -0.000557   4.418474e-08       301  HZ12M01         BF
# ...         ...        ...            ...       ...      ...        ...
# 1266  InN-Calb2   0.003120   2.468387e-59       566   HZ8M06         TH
# 1267  InN-Pvalb   0.002404   2.780207e-07       217   HZ8M06         TH
# 1268    InN-Vip   0.000063   1.179925e-03        47   HZ8M06         TH
# 1269    InN-Sst  -0.004588   4.278761e-02       138   HZ8M06         TH
# 1270  InN-Lamp5  -0.059421   2.171429e-01        15   HZ8M06         TH
#
#                   fullid
# 0     HZ12M01_coorect_BF
# 1     HZ12M01_coorect_BF
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame
# If not already done, load your dataframe
# df = pd.read_csv('your_data.csv')

# Get unique regions and fines
regions = df['region_abb'].unique()
fines = df['fine'].unique()

# Set up the figure with subplots (1 row, number of unique regions)
fig, axes = plt.subplots(1, len(regions), figsize=(15, 10), sharey=True)

# Loop through each region and plot
for i, region in enumerate(regions):
    # Filter data for each region
    data = df[df['region_abb'] == region]
    
    # Create a barplot for each subplot
    sns.barplot(x="Moran's I", y='fine', data=data, ax=axes[i], palette="viridis")
    
    # Set the title for each subplot
    axes[i].set_title(region)

# Adjust layout to avoid overlap
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# /var/folders/f_/dlk4nftn5s3bpdrpz9trm07m0000gn/T/ipykernel_7777/1280999164.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Moran's I", y='fine', data=data, ax=axes[i], palette="viridis")
# /Users/jay/micromamba/envs/stalign/lib/python3.11/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/jay/micromamba/envs/stalign/lib/python3.11/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...
