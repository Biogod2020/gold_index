# %%
palette = {
    'CA1': '#AA0DFD',       # ExN-CA1
    'CA2': '#F18266',       # ExN-CA2
    'CA3': '#F9A206',       # ExN-CA3
    'CTX-Ex': '#FF3357',    # ExN (general)
    'DG': '#584925',        # ExN-DG
    'Micro': '#820E56',     # Micro
    'SMC': '#825F45',       # SMC
    'Endo': '#996B2D',      # Endo
    'OPC': '#73E785',       # OPC
    'Astro': '#FF7620',     # Astro
    'Oligo': '#099963',     # Olig
    'Inh': '#2B92DF',       # InN (general)
    'LHb': '#0D46A0'        # MSN
}

# %%
# Set up the figure
plt.figure(figsize=(10, 7))

# Scatter plot without edges
sns.scatterplot(
    x=umap_df['X'], y=umap_df['Y'], hue=umap_df['top_level_cell_type'], 
    palette=palette, s=1, edgecolor=None, legend=True
)

# Calculate the center of each group based on the mean of X and Y for each top-level cell type
group_centers = umap_df.groupby('top_level_cell_type')[['X', 'Y']].mean()



# Remove axis lines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)

# Move legend outside and increase legend point size
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5), title="Cell Types", 
           fontsize=10, markerscale=2)

# Remove axis ticks
plt.xticks([])
plt.yticks([])

# Add axis labels (optional if needed)
plt.xlabel('UMAP 1')
plt.ylabel('UMAP 2')

# Show plot
plt.tight_layout()
plt.savefig("../article_figure/sup_figure/wx_umap_new_palette.pdf", dpi=300)
plt.show()
