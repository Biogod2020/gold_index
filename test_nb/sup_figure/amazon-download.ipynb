# %%
import boto3
import os

# Disable signing for public access
from botocore import UNSIGNED
from botocore.client import Config

# %%
# Define the S3 bucket names
buckets = {
    "single_cell_profiling": "sea-ad-single-cell-profiling",
    "quantitative_neuropathology": "sea-ad-quantitative-neuropathology",
    "spatial_transcriptomics": "sea-ad-spatial-transcriptomics"
}

# %%
# Create an S3 client with unsigned requests
s3 = boto3.client('s3', config=Config(signature_version=UNSIGNED))

# %%
import re

# Function to list files in the bucket with optional regex filter
def list_files(bucket_name, regex_pattern=None):
    print(f"Listing files in bucket: {bucket_name}")
    response = s3.list_objects_v2(Bucket=bucket_name)
    if 'Contents' in response:
        for item in response['Contents']:
            file_name = item['Key']
            if regex_pattern is None or re.search(regex_pattern, file_name):
                print(file_name)
    else:
        print(f"No files found in bucket {bucket_name}")

# Function to download all files in the bucket to a local folder
def download_bucket(bucket_name, local_dir):
    print(f"Downloading files from bucket: {bucket_name} to {local_dir}")
    os.makedirs(local_dir, exist_ok=True)
    response = s3.list_objects_v2(Bucket=bucket_name)
    
    if 'Contents' in response:
        for obj in response['Contents']:
            file_name = obj['Key']
            local_file_path = os.path.join(local_dir, file_name)
            os.makedirs(os.path.dirname(local_file_path), exist_ok=True)  # Create directories if needed
            
            print(f"Downloading {file_name}...")
            s3.download_file(bucket_name, file_name, local_file_path)
            print(f"Downloaded {file_name} to {local_file_path}")
    else:
        print(f"No files found in bucket {bucket_name}")

# %%
# Example usage: List files and download them
for key, bucket in buckets.items():
    list_files(bucket, regex_pattern='.*\.h5ad')  # List all files in the bucket
# Out:
# Listing files in bucket: sea-ad-single-cell-profiling
# MTG/ATACseq/SEAAD_MTG_ATACseq_all-nuclei.2024-02-13.h5ad
# MTG/ATACseq/SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H19.30.002_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H19.30.004_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H19.33.004_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.001_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.002_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.004_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.005_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.008_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.011_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.012_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.013_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.014_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.015_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.016_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.017_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.018_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.019_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.020_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.024_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.025_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.026_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.027_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.028_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.029_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.030_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.031_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.032_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.033_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.034_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.035_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.036_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.037_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.038_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.039_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.040_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.041_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.043_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.044_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.045_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H20.33.046_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.001_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.002_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.003_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.004_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.005_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.006_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.007_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.008_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.009_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.010_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.011_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.012_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.013_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.014_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.015_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.016_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.017_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.018_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.019_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.020_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.021_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.022_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.023_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.025_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.026_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.027_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.028_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.029_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.030_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.031_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.032_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.033_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.034_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.035_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.036_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.037_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.038_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.039_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.040_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.041_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.042_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.043_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.044_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.045_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.046_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/donor_objects/H21.33.047_SEAAD_MTG_ATACseq_final-nuclei.2024-02-13.h5ad
# MTG/ATACseq/previous_objects/SEAAD_MTG_ATACseq_all-nuclei.2023-05-08.h5ad
# MTG/ATACseq/previous_objects/SEAAD_MTG_ATACseq_final-nuclei.2023-05-08.h5ad
# MTG/RNAseq/Reference_MTG_RNAseq_all-nuclei.2022-06-07.h5ad
# MTG/RNAseq/Reference_MTG_RNAseq_final-nuclei.2022-06-07.h5ad
# MTG/RNAseq/SEAAD_MTG_RNAseq_all-nuclei.2024-02-13.h5ad
# MTG/RNAseq/SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H18.30.001_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H18.30.002_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H19.30.001_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H19.30.002_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H19.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.001_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.002_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.005_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.008_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.011_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.012_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.013_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.014_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.015_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.016_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.017_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.018_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.019_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.020_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.024_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.025_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.026_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.027_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.028_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.029_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.030_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.031_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.032_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.033_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.034_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.035_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.036_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.037_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.038_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.039_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.040_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.041_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.043_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.044_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.045_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H20.33.046_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H200.1023_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.001_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.002_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.003_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.004_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.005_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.006_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.007_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.008_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.009_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.010_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.011_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.012_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.013_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.014_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.015_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.016_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.017_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.018_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.019_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.020_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.021_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.022_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.023_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.025_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.026_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.027_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.028_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.029_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.030_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.031_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.032_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.033_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.034_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.035_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.036_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.037_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.038_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.039_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.040_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.041_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.042_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.043_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.044_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.045_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.046_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/donor_objects/H21.33.047_SEAAD_MTG_RNAseq_final-nuclei.2024-02-13.h5ad
# MTG/RNAseq/previous_objects/SEAAD_MTG_RNAseq_all-nuclei.2022-08-18.h5ad
# MTG/RNAseq/previous_objects/SEAAD_MTG_RNAseq_all-nuclei.2023-05-05.h5ad
# MTG/RNAseq/previous_objects/SEAAD_MTG_RNAseq_final-nuclei.2022-08-18.h5ad
# MTG/RNAseq/previous_objects/SEAAD_MTG_RNAseq_final-nuclei.2023-05-05.h5ad
# Listing files in bucket: sea-ad-quantitative-neuropathology
# Listing files in bucket: sea-ad-spatial-transcriptomics
# middle-temporal-gyrus/all_donors-h5ad/SEAAD_MTG_MERFISH.2024-02-13.h5ad

# %%
# Example usage: List files and download them
for key, bucket in buckets.items():
    
    download_bucket(bucket, f"./{key}")  # Download all files to a local directory
